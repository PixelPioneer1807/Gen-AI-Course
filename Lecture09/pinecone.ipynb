# %%
print("HELLO")
# Out:
# HELLO

# %%
# %pip install pinecone
# Out:
# ...
#   Using cached pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached pinecone_plugin_assistant-1.7.0-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached pinecone-7.3.0-py3-none-any.whl (587 kB)
# Using cached pinecone_plugin_assistant-1.7.0-py3-none-any.whl (239 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# ...
#
#   Attempting uninstall: packaging
#
#     Found existing installation: packaging 25.0
#
#     Uninstalling packaging-25.0:
#
#       Successfully uninstalled packaging-25.0
#
#    ---------- ----------------------------- 1/4 [packaging]
#    ---------- ----------------------------- 1/4 [packaging]
#    -------------------- ------------------- 2/4 [pinecone-plugin-assistant]
# ...

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="pcsk_45tSwx_DDjU4qDQNeorbtocz2S59tBckynJzC1Jz56ccVkBo8S3ywneg4cA2qRmLQP8x9a")

# %%
print(pc)

# %%
index_name = "first-test-index"

if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "first-test-index",
#         "metric": "cosine",
#         "host": "first-test-index-idf6jo4.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "cloud": "aws",
#                 "region": "us-east-1"
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
import os 
import requests

# %%
def generate_embeddings(text_list):
    url = "https://api.euron.one/api/v1/euri/alpha/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer euri-5ecfb5f7c1ad275ca925fa79e9d74e24a291fa874d025f40494fb439e4682976"
    }
    payload = {
        "input": text_list,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    
    embeddings = [item["embedding"] for item in response.json()["data"]]
    
    return embeddings

# %%
data = [
    "Cricket is a sport played between two teams of eleven players each.",
    "The game involves batting, bowling, and fielding across innings.",
    "A bowler delivers the ball while a batter tries to score runs.",
    "Matches can be played in various formats like Test, ODI, or T20.",
    "Teams aim to outscore their opponents by hitting and running.",
    "Batsmen must protect their wicket while maximizing run potential.",
    "Fielders support bowlers by preventing runs and taking catches.",
    "Umpires ensure fair play and make key decisions on the field.",
    "The pitch is central to the game, influencing bounce and spin.",
    "A fast outfield can help batters score boundaries quickly.",
    "Bowlers use pace, swing, and spin to outsmart the batsman.",
    "T20 cricket is known for its explosive scoring and entertainment.",
    "In Tests, strategy and patience are vital for long-term success.",
    "One Day Internationals strike a balance between aggression and defense.",
    "Cricket has passionate fans who follow their favorite teams religiously.",
    "Stadiums erupt with cheer when a player hits a six or takes a wicket.",
    "Captains play a crucial role in tactics and on-field decisions.",
    "The DRS system helps review close calls using technology.",
    "Legendary players like Sachin Tendulkar have inspired generations.",
    "Young cricketers dream of playing for their national side one day.",
    "Practice and mental toughness are essential for professional cricketers.",
    "Rain interruptions can affect the momentum of a closely fought match.",
    "Commentary adds depth and excitement for television viewers.",
    "Cricket is evolving with new leagues and rising global popularity.",
    "Every delivery, every run, and every catch can change the course of a game."
]

# %%
all_embeddings=generate_embeddings(data)

# %%
index=pc.Index('first-test-index')
vectors = [(f"item_id_{i}", all_embeddings[i],{"text":data[i]}) for i in range(len(all_embeddings))]
index.upsert(vectors)
# Out:
# {'upserted_count': 25}

# %%
index.fetch(ids=["item_id_3"])
# Out:
# FetchResponse(namespace='', vectors={'item_id_3': Vector(id='item_id_3', values=[-0.0436121635, -0.0138922371, 0.0951381698, -0.0423003584, 0.0169136915, -0.00913963, 0.0381283835, -0.0212146938, 0.000431780296, 0.0184405465, 0.0319779515, -0.0255264491, 0.00306177605, 0.00791922, 0.051612027, -0.0170319695, -0.0235264823, 0.0149782402, 0.011741736, 0.0462787859, 0.0511819273, 0.0376337692, 0.00238302397, -0.00605903706, 0.0189029053, -0.0238275528, -0.0838695467, 0.000297542, 0.032279022, 0.00273113651, 0.00338435126, 0.000421699835, -0.0430745371, -0.0590957701, 0.026709225, -0.0115804486, 0.0378918312, 0.0128707495, 0.0108546549, -0.0184297953, 0.0146341603, -0.0194727872, 0.00751062529, -0.00541657489, 0.0127954818, -0.00376606523, -0.00698375236, -0.0647300854, -0.0208383556, 0.0426444374, -0.0256769843, 0.0186018348, 0.00895683747, 0.000446565, 0.0407735035, 0.00858587585, -0.0140857827, 0.034063939, 0.0636548325, -0.0314833373, -0.0238920674, 0.00143949175, 0.0428594872, -0.01
# ...

# %%
# Now let's fetc the data based on similarity 

text="I love t20 cricket more than odi"

# %%
embedding_tosearch=generate_embeddings(text)
print(type(embedding_tosearch))
# Out:
# <class 'list'>

# %%
result=index.query(vector=embedding_tosearch,
            top_k=5,
            include_metadata=True
            )

print(result)
# Out:
# {'matches': [{'id': 'item_id_11',
#               'metadata': {'text': 'T20 cricket is known for its explosive '
#                                    'scoring and entertainment.'},
#               'score': 0.589392483,
#               'values': []},
#              {'id': 'item_id_3',
#               'metadata': {'text': 'Matches can be played in various formats '
#                                    'like Test, ODI, or T20.'},
#               'score': 0.4790169,
#               'values': []},
#              {'id': 'item_id_14',
#               'metadata': {'text': 'Cricket has passionate fans who follow '
#                                    'their favorite teams religiously.'},
#               'score': 0.470817775,
#               'values': []},
#              {'id': 'item_id_23',
#               'metadata': {'text': 'Cricket is evolving with new leagues and '
#                                    'rising global popularity.'},
#               'score': 0.429794937,
# ...

# %%
# Similar things are done using waeviate and FAISS vector dbs  use according to your requirement, 
# the difference is just in their syntaxes and Stuff life algos used to do similarity searches
